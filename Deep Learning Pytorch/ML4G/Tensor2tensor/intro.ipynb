# %%
Welcome to the Tensor2Tensor Colab

# %%
# Imports we need.
import sys
if 'google.colab' in sys.modules: # Colab-only TensorFlow version selector
  # %tensorflow_version 1.x
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os
import collections

from tensor2tensor import models
from tensor2tensor import problems
from tensor2tensor.layers import common_layers
from tensor2tensor.utils import trainer_lib
from tensor2tensor.utils import t2t_model
from tensor2tensor.utils import registry
from tensor2tensor.utils import metrics

# Enable TF Eager execution
tfe = tf.contrib.eager
tfe.enable_eager_execution()

# Other setup
Modes = tf.estimator.ModeKeys

# Setup some directories
data_dir = os.path.expanduser("~/t2t/data")
tmp_dir = os.path.expanduser("~/t2t/tmp")
train_dir = os.path.expanduser("~/t2t/train")
checkpoint_dir = os.path.expanduser("~/t2t/checkpoints")
tf.gfile.MakeDirs(data_dir)
tf.gfile.MakeDirs(tmp_dir)
tf.gfile.MakeDirs(train_dir)
tf.gfile.MakeDirs(checkpoint_dir)
gs_data_dir = "gs://tensor2tensor-data"
gs_ckpt_dir = "gs://tensor2tensor-checkpoints/"

# A Problem is a dataset together with some fixed pre-processing.
# It could be a translation dataset with a specific tokenization,
# or an image dataset with a specific resolution.
#
# There are many problems available in Tensor2Tensor
problems.available()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /workspaces/python/Deep Learning Pytorch/ML4G/Tensor2tensor/intro.ipynb Cellule 2 line 1
#       <a href='vscode-notebook-cell://codespaces%2Brefactored-cod-p6q4rjgvrwp3rw74/workspaces/python/Deep%20Learning%20Pytorch/ML4G/Tensor2tensor/intro.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> import os
#       <a href='vscode-notebook-cell://codespaces%2Brefactored-cod-p6q4rjgvrwp3rw74/workspaces/python/Deep%20Learning%20Pytorch/ML4G/Tensor2tensor/intro.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> import collections
# ---> <a href='vscode-notebook-cell://codespaces%2Brefactored-cod-p6q4rjgvrwp3rw74/workspaces/python/Deep%20Learning%20Pytorch/ML4G/Tensor2tensor/intro.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a> from tensor2tensor import models
#      <a href='vscode-notebook-cell://codespaces%2Brefactored-cod-p6q4rjgvrwp3rw74/workspaces/python/Deep%20Learning%20Pytorch/ML4G/Tensor2tensor/intro.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a> from tensor2tensor import problems
#      <a href='vscode-notebook-cell://codespaces%2Brefactored-cod-p6q4rjgvrwp3rw74/workspaces/python/Deep%20Learning%20Pytorch/ML4G/Tensor2tensor/intro.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a> from tensor2tensor.layers import common_layers
#
# File ~/.python/current/lib/python3.10/site-packages/tensor2tensor/models/__init__.py:25
#      21 import six
#      23 # pylint: disable=unused-import
# ---> 25 from tensor2tensor.layers import modalities  # pylint: disable=g-import-not-at-top
#      26 from tensor2tensor.models import basic
#      27 from tensor2tensor.models import bytenet
#
# File ~/.python/current/lib/python3.10/site-packages/tensor2tensor/layers/modalities.py:28
#      24 from __future__ import print_function
#      26 from six.moves import range  # pylint: disable=redefined-builtin
# ---> 28 from tensor2tensor.layers import common_attention
#      29 from tensor2tensor.layers import common_audio
#      30 from tensor2tensor.layers import common_image_attention as cia
#
# File ~/.python/current/lib/python3.10/site-packages/tensor2tensor/layers/common_attention.py:32
#      29 from six.moves import range  # pylint: disable=redefined-builtin
#      30 from six.moves import zip  # pylint: disable=redefined-builtin
# ---> 32 from tensor2tensor.layers import area_attention
#      33 from tensor2tensor.layers import common_layers
#      34 from tensor2tensor.utils import contrib
#
# File ~/.python/current/lib/python3.10/site-packages/tensor2tensor/layers/area_attention.py:23
#      21 import numpy as np
#      22 from six.moves import range  # pylint: disable=redefined-builtin
# ---> 23 from tensor2tensor.layers import common_layers
#      24 import tensorflow.compat.v1 as tf
#      27 def lengths_to_area_mask(feature_length, length, max_area_size):
#
# File ~/.python/current/lib/python3.10/site-packages/tensor2tensor/layers/common_layers.py:32
#      30 from tensor2tensor.utils import contrib
#      31 import tensorflow.compat.v1 as tf
# ---> 32 import tensorflow_probability as tfp
#      34 from tensorflow.python.framework import function
#      35 from tensorflow.python.framework import ops
#
# File ~/.python/current/lib/python3.10/site-packages/tensorflow_probability/__init__.py:75
#      71 del _ensure_tf_install
#      74 # from tensorflow_probability.google import staging  # DisableOnExport
# ---> 75 from tensorflow_probability.python import *  # pylint: disable=wildcard-import
#      76 from tensorflow_probability.python.version import __version__
#      77 # pylint: enable=g-import-not-at-top
#
# File ~/.python/current/lib/python3.10/site-packages/tensorflow_probability/python/__init__.py:21
#      18 from __future__ import division
#      19 from __future__ import print_function
# ---> 21 from tensorflow_probability.python import bijectors
#      22 from tensorflow_probability.python import debugging
#      23 from tensorflow_probability.python import distributions
#
# File ~/.python/current/lib/python3.10/site-packages/tensorflow_probability/python/bijectors/__init__.py:23
#      19 from __future__ import print_function
#      21 # pylint: disable=unused-import,wildcard-import,line-too-long,g-importing-member
# ---> 23 from tensorflow_probability.python.bijectors.absolute_value import AbsoluteValue
#      24 from tensorflow_probability.python.bijectors.affine import Affine
#      25 from tensorflow_probability.python.bijectors.affine_linear_operator import AffineLinearOperator
#
# File ~/.python/current/lib/python3.10/site-packages/tensorflow_probability/python/bijectors/absolute_value.py:23
#      19 from __future__ import print_function
#      21 import tensorflow.compat.v2 as tf
# ---> 23 from tensorflow_probability.python.bijectors import bijector
#      24 from tensorflow_probability.python.internal import assert_util
#      25 from tensorflow_probability.python.internal import distribution_util
#
# File ~/.python/current/lib/python3.10/site-packages/tensorflow_probability/python/bijectors/bijector.py:33
#      30 import tensorflow as tf
#      32 from tensorflow_probability.python.internal import assert_util
# ---> 33 from tensorflow_probability.python.internal import distribution_util
#      34 from tensorflow_probability.python.internal import dtype_util
#      35 from tensorflow_probability.python.internal import tensorshape_util
#
# File ~/.python/current/lib/python3.10/site-packages/tensorflow_probability/python/internal/distribution_util.py:29
#      27 from tensorflow_probability.python.internal import assert_util
#      28 from tensorflow_probability.python.internal import dtype_util
# ---> 29 from tensorflow_probability.python.internal import prefer_static
#      30 from tensorflow_probability.python.internal import reparameterization
#      31 from tensorflow_probability.python.internal import tensorshape_util
#
# File ~/.python/current/lib/python3.10/site-packages/tensorflow_probability/python/internal/prefer_static.py:193
#     185 concat = _prefer_static(
#     186     tf.concat,
#     187     lambda values, axis, name='concat': np.concatenate(values, axis))
#     189 equal = _prefer_static(
#     190     tf.equal,
#     191     lambda x, y, name=None: np.equal(x, y))
# --> 193 greater = _prefer_static(
#     194     tf.greater,
#     195     lambda x, y, name=None: np.greater(x, y))
#     197 less = _prefer_static(
#     198     tf.less,
#     199     lambda x, y, name=None: np.less(x, y))
#     201 logical_and = _prefer_static(
#     202     tf.logical_and,
#     203     lambda x, y, name=None: np.logical_and(x, y))
#
# File ~/.python/current/lib/python3.10/site-packages/tensorflow_probability/python/internal/prefer_static.py:47, in _prefer_static(original_fn, static_fn)
#      45 static_spec = tf_inspect.getfullargspec(static_fn)
#      46 if original_spec != static_spec:
# ---> 47   raise ValueError(
#      48       'Arg specs do not match: original={}, static={}, fn={}'.format(
#      49           original_spec, static_spec, original_fn))
#      50 @decorator.decorator
#      51 def wrap(wrapped_fn, *args, **kwargs):
#      52   del wrapped_fn
#
# ValueError: Arg specs do not match: original=FullArgSpec(args=['x', 'y', 'name'], varargs=None, varkw=None, defaults=(None,), kwonlyargs=[], kwonlydefaults=None, annotations={'return': tensorflow.security.fuzzing.py.annotation_types.TensorFuzzingAnnotation[tensorflow.security.fuzzing.py.annotation_types.Bool], 'x': tensorflow.security.fuzzing.py.annotation_types.TensorFuzzingAnnotation[~TV_Greater_T], 'y': tensorflow.security.fuzzing.py.annotation_types.TensorFuzzingAnnotation[~TV_Greater_T]}), static=FullArgSpec(args=['x', 'y', 'name'], varargs=None, varkw=None, defaults=(None,), kwonlyargs=[], kwonlydefaults=None, annotations={}), fn=<function greater at 0x7f3ddcdc5510>

# %%
# Imports we need.
import sys
if 'google.colab' in sys.modules: # Colab-only TensorFlow version selector
  # %tensorflow_version 1.x
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import os
import collections

from tensor2tensor import models
from tensor2tensor import problems
from tensor2tensor.layers import common_layers
from tensor2tensor.utils import trainer_lib
from tensor2tensor.utils import t2t_model
from tensor2tensor.utils import registry
from tensor2tensor.utils import metrics

# Enable TF Eager execution
tfe = tf.contrib.eager
tfe.enable_eager_execution()

# Other setup
Modes = tf.estimator.ModeKeys

# Setup some directories
data_dir = os.path.expanduser("~/t2t/data")
tmp_dir = os.path.expanduser("~/t2t/tmp")
train_dir = os.path.expanduser("~/t2t/train")
checkpoint_dir = os.path.expanduser("~/t2t/checkpoints")
tf.gfile.MakeDirs(data_dir)
tf.gfile.MakeDirs(tmp_dir)
tf.gfile.MakeDirs(train_dir)
tf.gfile.MakeDirs(checkpoint_dir)
gs_data_dir = "gs://tensor2tensor-data"
gs_ckpt_dir = "gs://tensor2tensor-checkpoints/"


# A Problem is a dataset together with some fixed pre-processing.
# It could be a translation dataset with a specific tokenization,
# or an image dataset with a specific resolution.
#
# There are many problems available in Tensor2Tensor
problems.available()


# Fetch the MNIST problem
mnist_problem = problems.problem("image_mnist")
# The generate_data method of a problem will download data and process it into
# a standard format ready for training and evaluation.
mnist_problem.generate_data(data_dir, tmp_dir)

# Now let's see the training MNIST data as Tensors.
mnist_example = tfe.Iterator(mnist_problem.dataset(Modes.TRAIN, data_dir)).next()
image = mnist_example["inputs"]
label = mnist_example["targets"]

plt.imshow(image.numpy()[:, :, 0].astype(np.float32), cmap=plt.get_cmap('gray'))
print("Label: %d" % label.numpy())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /workspaces/python/Deep Learning Pytorch/ML4G/Tensor2tensor/intro.ipynb Cellule 3 line 1
#       <a href='vscode-notebook-cell://codespaces%2Brefactored-cod-p6q4rjgvrwp3rw74/workspaces/python/Deep%20Learning%20Pytorch/ML4G/Tensor2tensor/intro.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> import os
#       <a href='vscode-notebook-cell://codespaces%2Brefactored-cod-p6q4rjgvrwp3rw74/workspaces/python/Deep%20Learning%20Pytorch/ML4G/Tensor2tensor/intro.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> import collections
# ---> <a href='vscode-notebook-cell://codespaces%2Brefactored-cod-p6q4rjgvrwp3rw74/workspaces/python/Deep%20Learning%20Pytorch/ML4G/Tensor2tensor/intro.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a> from tensor2tensor import models
#      <a href='vscode-notebook-cell://codespaces%2Brefactored-cod-p6q4rjgvrwp3rw74/workspaces/python/Deep%20Learning%20Pytorch/ML4G/Tensor2tensor/intro.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a> from tensor2tensor import problems
#      <a href='vscode-notebook-cell://codespaces%2Brefactored-cod-p6q4rjgvrwp3rw74/workspaces/python/Deep%20Learning%20Pytorch/ML4G/Tensor2tensor/intro.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a> from tensor2tensor.layers import common_layers
#
# File ~/.python/current/lib/python3.10/site-packages/tensor2tensor/models/__init__.py:25
#      21 import six
#      23 # pylint: disable=unused-import
# ---> 25 from tensor2tensor.layers import modalities  # pylint: disable=g-import-not-at-top
#      26 from tensor2tensor.models import basic
#      27 from tensor2tensor.models import bytenet
#
# File ~/.python/current/lib/python3.10/site-packages/tensor2tensor/layers/modalities.py:28
#      24 from __future__ import print_function
#      26 from six.moves import range  # pylint: disable=redefined-builtin
# ---> 28 from tensor2tensor.layers import common_attention
#      29 from tensor2tensor.layers import common_audio
#      30 from tensor2tensor.layers import common_image_attention as cia
#
# File ~/.python/current/lib/python3.10/site-packages/tensor2tensor/layers/common_attention.py:32
#      29 from six.moves import range  # pylint: disable=redefined-builtin
#      30 from six.moves import zip  # pylint: disable=redefined-builtin
# ---> 32 from tensor2tensor.layers import area_attention
#      33 from tensor2tensor.layers import common_layers
#      34 from tensor2tensor.utils import contrib
#
# File ~/.python/current/lib/python3.10/site-packages/tensor2tensor/layers/area_attention.py:23
#      21 import numpy as np
#      22 from six.moves import range  # pylint: disable=redefined-builtin
# ---> 23 from tensor2tensor.layers import common_layers
#      24 import tensorflow.compat.v1 as tf
#      27 def lengths_to_area_mask(feature_length, length, max_area_size):
#
# File ~/.python/current/lib/python3.10/site-packages/tensor2tensor/layers/common_layers.py:32
#      30 from tensor2tensor.utils import contrib
#      31 import tensorflow.compat.v1 as tf
# ---> 32 import tensorflow_probability as tfp
#      34 from tensorflow.python.framework import function
#      35 from tensorflow.python.framework import ops
#
# File ~/.python/current/lib/python3.10/site-packages/tensorflow_probability/__init__.py:75
#      71 del _ensure_tf_install
#      74 # from tensorflow_probability.google import staging  # DisableOnExport
# ---> 75 from tensorflow_probability.python import *  # pylint: disable=wildcard-import
#      76 from tensorflow_probability.python.version import __version__
#      77 # pylint: enable=g-import-not-at-top
#
# File ~/.python/current/lib/python3.10/site-packages/tensorflow_probability/python/__init__.py:21
#      18 from __future__ import division
#      19 from __future__ import print_function
# ---> 21 from tensorflow_probability.python import bijectors
#      22 from tensorflow_probability.python import debugging
#      23 from tensorflow_probability.python import distributions
#
# File ~/.python/current/lib/python3.10/site-packages/tensorflow_probability/python/bijectors/__init__.py:23
#      19 from __future__ import print_function
#      21 # pylint: disable=unused-import,wildcard-import,line-too-long,g-importing-member
# ---> 23 from tensorflow_probability.python.bijectors.absolute_value import AbsoluteValue
#      24 from tensorflow_probability.python.bijectors.affine import Affine
#      25 from tensorflow_probability.python.bijectors.affine_linear_operator import AffineLinearOperator
#
# File ~/.python/current/lib/python3.10/site-packages/tensorflow_probability/python/bijectors/absolute_value.py:23
#      19 from __future__ import print_function
#      21 import tensorflow.compat.v2 as tf
# ---> 23 from tensorflow_probability.python.bijectors import bijector
#      24 from tensorflow_probability.python.internal import assert_util
#      25 from tensorflow_probability.python.internal import distribution_util
#
# File ~/.python/current/lib/python3.10/site-packages/tensorflow_probability/python/bijectors/bijector.py:33
#      30 import tensorflow as tf
#      32 from tensorflow_probability.python.internal import assert_util
# ---> 33 from tensorflow_probability.python.internal import distribution_util
#      34 from tensorflow_probability.python.internal import dtype_util
#      35 from tensorflow_probability.python.internal import tensorshape_util
#
# File ~/.python/current/lib/python3.10/site-packages/tensorflow_probability/python/internal/distribution_util.py:29
#      27 from tensorflow_probability.python.internal import assert_util
#      28 from tensorflow_probability.python.internal import dtype_util
# ---> 29 from tensorflow_probability.python.internal import prefer_static
#      30 from tensorflow_probability.python.internal import reparameterization
#      31 from tensorflow_probability.python.internal import tensorshape_util
#
# File ~/.python/current/lib/python3.10/site-packages/tensorflow_probability/python/internal/prefer_static.py:193
#     185 concat = _prefer_static(
#     186     tf.concat,
#     187     lambda values, axis, name='concat': np.concatenate(values, axis))
#     189 equal = _prefer_static(
#     190     tf.equal,
#     191     lambda x, y, name=None: np.equal(x, y))
# --> 193 greater = _prefer_static(
#     194     tf.greater,
#     195     lambda x, y, name=None: np.greater(x, y))
#     197 less = _prefer_static(
#     198     tf.less,
#     199     lambda x, y, name=None: np.less(x, y))
#     201 logical_and = _prefer_static(
#     202     tf.logical_and,
#     203     lambda x, y, name=None: np.logical_and(x, y))
#
# File ~/.python/current/lib/python3.10/site-packages/tensorflow_probability/python/internal/prefer_static.py:47, in _prefer_static(original_fn, static_fn)
#      45 static_spec = tf_inspect.getfullargspec(static_fn)
#      46 if original_spec != static_spec:
# ---> 47   raise ValueError(
#      48       'Arg specs do not match: original={}, static={}, fn={}'.format(
#      49           original_spec, static_spec, original_fn))
#      50 @decorator.decorator
#      51 def wrap(wrapped_fn, *args, **kwargs):
#      52   del wrapped_fn
#
# ValueError: Arg specs do not match: original=FullArgSpec(args=['x', 'y', 'name'], varargs=None, varkw=None, defaults=(None,), kwonlyargs=[], kwonlydefaults=None, annotations={'return': tensorflow.security.fuzzing.py.annotation_types.TensorFuzzingAnnotation[tensorflow.security.fuzzing.py.annotation_types.Bool], 'x': tensorflow.security.fuzzing.py.annotation_types.TensorFuzzingAnnotation[~TV_Greater_T], 'y': tensorflow.security.fuzzing.py.annotation_types.TensorFuzzingAnnotation[~TV_Greater_T]}), static=FullArgSpec(args=['x', 'y', 'name'], varargs=None, varkw=None, defaults=(None,), kwonlyargs=[], kwonlydefaults=None, annotations={}), fn=<function greater at 0x7f3ddcdc5510>
